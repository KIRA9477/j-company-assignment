# %%
import pandas as ip

# %%
d=ip.read_csv('/content/drive/MyDrive/Life Expectancy Data.csv')

# %%
print(d)
# Out:
#           Country  Year  ... Income composition of resources  Schooling
# 0     Afghanistan  2015  ...                           0.479       10.1
# 1     Afghanistan  2014  ...                           0.476       10.0
# 2     Afghanistan  2013  ...                           0.470        9.9
# 3     Afghanistan  2012  ...                           0.463        9.8
# 4     Afghanistan  2011  ...                           0.454        9.5
# ...           ...   ...  ...                             ...        ...
# 2933     Zimbabwe  2004  ...                           0.407        9.2
# 2934     Zimbabwe  2003  ...                           0.418        9.5
# 2935     Zimbabwe  2002  ...                           0.427       10.0
# 2936     Zimbabwe  2001  ...                           0.427        9.8
# 2937     Zimbabwe  2000  ...                           0.434        9.8
#
# [2938 rows x 22 columns]

# %%
x=d[' BMI ']
y=d['Life expectancy ']

# %%
from matplotlib import pyplot as al

# %%
al.scatter(x,y)

# %%
al.plot(x,y)

# %%
x=d['Adult Mortality']
al.scatter(x,y)
al.plot(x,y)

# %%
x=d['infant deaths']
al.scatter(x,y)
al.plot(x,y)

# %%
x=d['percentage expenditure']
al.scatter(x,y)
al.plot(x,y)

# %%
x=d['Hepatitis B']
al.scatter(x,y)
al.plot(x,y)

# %%
x=d['Measles ']
al.scatter(x,y)
al.plot(x,y)

# %%
x=d['under-five deaths ']
al.plot(x,y)
al.scatter(x,y)

# %%
x=d['Total expenditure']
al.plot(x,y)
al.scatter(x,y)

# %%
x=d['Diphtheria ']
al.scatter(x,y)
al.plot(x,y)

# %%
x=d[' HIV/AIDS']
al.scatter(x,y)
al.plot(x,y)

# %%
x=d['GDP']
al.scatter(x,y)
al.plot(x,y)

# %%
x=d['Population']
al.scatter(x,y)
al.plot(x,y)

# %%
x=d[' thinness  1-19 years']
al.scatter(x,y)
al.plot(x,y)

# %%
x=d[' thinness 5-9 years']
al.scatter(x,y)
al.plot(x,y)

# %%
x=d['Schooling']
al.scatter(x,y)
al.plot(x,y)

# %%
x=d['Income composition of resources']
al.scatter(x,y)
al.plot(x,y)

# %%
x=d['Polio']
al.scatter(x,y)
al.plot(x,y)
